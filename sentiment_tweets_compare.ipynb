# %% [markdown]
# <a href="https://colab.research.google.com/github/souradipta93/NLP/blob/main/sentiment_tweets_compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import defaultdict
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
data1 = pd.read_csv('chelsea.csv')
data1.head()
# Out:
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                user_id            status_id            created_at  \
# 0  1242159944809537537  1398974961679843329  2021-05-30T12:09:57Z
# 1            191963248  1398974872987095043  2021-05-30T12:09:36Z
# 2  1267197215635726336  1398974708142329859  2021-05-30T12:08:56Z
# 3  1351495060492267522  1398974699124793345  2021-05-30T12:08:54Z
# 4  1351495060492267522  1398753380005302273  2021-05-29T21:29:28Z
#
#     screen_name                                               text  \
# 0  rolexhesham3  For sale #ChelseaChampions #ChelseaFC #Chelsea...
# 1   MATRIXALIVE  I'm supporting #Chelsea in the #HeinekenUCLLiv...
# 2      doge4you  &lt;도지코인 시세&gt;\nDOGE/USDT(Binance): 0.30722\n...
# 3   Zakstudios1  "To go through a campaign like that."\n\nFrom ...
# ...

# %%
data2 = pd.read_csv('mancity.csv')
data2.head()
# Out:
#               user_id            status_id            created_at  \
# 0           391617721  1398986413769691138  2021-05-30T12:55:27Z
# 1  803168687381499904  1398985616809992194  2021-05-30T12:52:17Z
# 2            21448506  1398985545058029569  2021-05-30T12:52:00Z
# 3            21448506  1398292050676797452  2021-05-28T14:56:18Z
# 4            21448506  1398293326810554370  2021-05-28T15:01:22Z
#
#        screen_name                                               text  \
# 0         emsgems7  Pic 1, Harrison drawing his favourite player @...
# 1  footballMLHbook  Love this!\n#Gazza #Gascoigne #Kane #Dele #Son...
# 2      Conversator  @ESPNFC #mancity still Champions of England fo...
# 3      Conversator  Watch the #mancity team train for tomorrow,  t...
# 4      Conversator  My nerves will kick in only if City is within ...
#
#                 source  display_text_width  reply_to_status_id  \
# 0   Twitter for iPhone                 231                 NaN
# ...

# %%
df1 = data1[['text']]
df1.head()
# Out:
#                                                 text
# 0  For sale #ChelseaChampions #ChelseaFC #Chelsea...
# 1  I'm supporting #Chelsea in the #HeinekenUCLLiv...
# 2  &lt;도지코인 시세&gt;\nDOGE/USDT(Binance): 0.30722\n...
# 3  "To go through a campaign like that."\n\nFrom ...
# 4  Wow 👏\n\nNGolo Kante.\n\n#Kante #Chelsea #cfc ...

# %%
df2 = data2[['text']]
df2.head()
# Out:
#                                                 text
# 0  Pic 1, Harrison drawing his favourite player @...
# 1  Love this!\n#Gazza #Gascoigne #Kane #Dele #Son...
# 2  @ESPNFC #mancity still Champions of England fo...
# 3  Watch the #mancity team train for tomorrow,  t...
# 4  My nerves will kick in only if City is within ...

# %%
def score_speaker(speaker_df):
    df_dict = {}
    for i,response in speaker_df.iterrows():
        scorer = SentimentIntensityAnalyzer()
        scores = scorer.polarity_scores(response.text)
        df_dict[i] = scores
    df = pd.DataFrame.from_dict(df_dict)
    df = df.T
    return df

# %%
# %time df_sent1 = score_speaker(df1)
# Out:
# Wall time: 6min 3s

# %%
# %time df_sent2 = score_speaker(df2)
# Out:
# Wall time: 3min 32s

# %%
df_sent1['user']=data1['screen_name']
df_sent2['user']=data2['screen_name']
df_sent1['created_at']=data1['created_at']
df_sent2['created_at']=data2['created_at']

# %%
df_sent1.head()
# Out:
#      neg    neu    pos  compound          user            created_at
# 0  0.000  1.000  0.000    0.0000  rolexhesham3  2021-05-30T12:09:57Z
# 1  0.109  0.733  0.158    0.4003   MATRIXALIVE  2021-05-30T12:09:36Z
# 2  0.042  0.958  0.000   -0.0772      doge4you  2021-05-30T12:08:56Z
# 3  0.000  0.799  0.201    0.7430   Zakstudios1  2021-05-30T12:08:54Z
# 4  0.000  0.703  0.297    0.5859   Zakstudios1  2021-05-29T21:29:28Z

# %%
df_sent1.to_csv('chelsea_sent.csv')
df_sent2.to_csv('mancity_sent.csv')
