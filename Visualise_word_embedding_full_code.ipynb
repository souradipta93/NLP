# %% [markdown]
# <a href="https://colab.research.google.com/github/souradipta93/NLP/blob/main/Visualise_word_embedding_full_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualise word vectors

# %%
import re, string 
import numpy as np
import pandas as pd   
from collections import defaultdict
import spacy
from sklearn.manifold import TSNE
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('bbctext.csv')

# %%
df.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
#Function for pre-processing
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    # Remove a sentence if it is only two word long
    if len(text) > 2:
        return ' '.join(word for word in text.split() if word not in STOPWORDS)

# %%
#Apply the function
df_clean = pd.DataFrame(df.text.apply(lambda x: preprocess_text(x)))

# %%
import spacy 
  
nlp = spacy.load('en_core_web_sm')

# %%
#function to lemmatize text
def lemmatizer(text):        
    sent = []
    doc = nlp(text)
    for word in doc:
        sent.append(word.lemma_)
    return " ".join(sent)

# %%
df_clean["text_lemmatize"] =  df_clean.apply(lambda x: lemmatizer(x['text']), axis=1)
df_clean['text_lemmatize_clean'] = df_clean['text_lemmatize'].str.replace('-PRON-', '')

# %%
#tokenize text
sentences = [row.split() for row in df_clean['text_lemmatize_clean']]
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
        
sorted(word_freq, key=word_freq.get, reverse=True)[:15]
# Out:
# ['say',
#  'mr',
#  'year',
#  'would',
#  'make',
#  'also',
#  'people',
#  'new',
#  'we',
#  'one',
#  'take',
#  'go',
#  'good',
#  'could',
#  'use']

# %% [markdown]
# - size:The number of dimensions of the embedding, e.g. the length of the dense vector to represent each token (word).
# - window:The maximum distance between a target word and words around the target word.
# - min_count: The minimum count of words to consider when training the model; words with an occurrence less than this count will be ignored.
# - workers:The number of threads to use while training.
# - sg:The training algorithm, either CBOW (0) or skip gram (1)

# %% [markdown]
# #Build the word2vec model
# w2v_model = Word2Vec(min_count=400,
#                      window=3,
#                      size=30,
#                      workers=4)

# %%
w2v_model = Word2Vec(vector_size=30,
                window=3,
                min_count=400,
                workers=4)

# %%
#Prepare the model vocabulary
w2v_model.build_vocab(sentences)

# %%
#Train word vectors
w2v_model.train(sentences, 
                total_examples=w2v_model.corpus_count, 
                epochs=2)
w2v_model.init_sims(replace=True) 
#When we do not plan to train the model any further, we use this line of code to make the model more memory-efficient.

# %%
w2v_model.wv.key_to_index
# Out:
# {'say': 0,
#  'mr': 1,
#  'year': 2,
#  'would': 3,
#  'make': 4,
#  'also': 5,
#  'people': 6,
#  'new': 7,
#  'we': 8,
#  'one': 9,
#  'take': 10,
#  'go': 11,
#  'good': 12,
#  'could': 13,
#  'use': 14,
#  'game': 15,
#  'get': 16,
#  'time': 17,
#  '£': 18,
#  'last': 19,
#  'first': 20,
#  'world': 21,
#  'government': 22,
#  'well': 23,
#  'come': 24,
#  'two': 25,
#  'see': 26,
#  'show': 27,
#  'film': 28,
#  'play': 29,
#  'company': 30,
#  'uk': 31,
#  'tell': 32,
#  'work': 33,
#  'firm': 34,
#  'give': 35,
#  'want': 36,
#  'add': 37,
#  'back': 38,
#  'win': 39,
#  'like': 40,
#  'number': 41,
#  'service': 42,
#  'include': 43,
#  'think': 44,
#  'way': 45,
#  'music': 46,
#  'month': 47,
#  'market': 48,
#  'many': 49,
#  'country': 50,
#  'player': 51,
#  'plan': 52,
#  'set': 53,
#  'labour': 54,
#  'need': 55,
#  'week': 56,
#  'next': 57,
#  'party': 58,
#  'report': 59,
#  'bbc': 60,
#  'three': 61,
#  'look': 62,
#  'big': 63,
#  'minister': 64,
#  'sale': 65,
#  'home': 66,
#  'election': 67,
#  'may': 68,
#  'call': 69,
#  'million': 70,
#  'day': 71,
#  'expect': 72,
#  'rise': 73,
#  'technology': 74,
#  'right': 75,
#  'find': 76,
#  'know': 77,
#  'second': 78,
#  'award': 79,
#  'mobile': 80,
#  'still': 81,
#  'group': 82,
#  'start': 83,
#  'part': 84,
#  'help': 85,
#  'england': 86,
#  'top': 87,
#  'end': 88,
#  'much': 89,
#  'claim': 90,
#  'phone': 91,
#  'since': 92,
#  'offer': 93,
#  'blair': 94,
#  'move': 95,
#  'high': 96,
#  'lead': 97,
#  'early': 98,
#  'try': 99,
#  'put': 100,
#  'share': 101,
#  'become': 102,
#  'public': 103,
#  'system': 104,
#  'record': 105,
#  'change': 106,
#  'run': 107,
#  'hold': 108,
#  'issue': 109,
#  'european': 110,
#  'star': 111,
#  'british': 112,
#  'deal': 113,
#  'believe': 114,
#  'increase': 115,
#  'great': 116,
#  'news': 117,
#  'follow': 118,
#  'place': 119,
#  'price': 120,
#  'however': 121,
#  'tv': 122,
#  'face': 123,
#  'bank': 124,
#  'even': 125,
#  'open': 126,
#  'director': 127,
#  'pay': 128,
#  'mean': 129,
#  'business': 130,
#  'five': 131,
#  'tory': 132,
#  'cost': 133,
#  'economy': 134,
#  'fall': 135,
#  'user': 136,
#  'hope': 137,
#  'already': 138,
#  'man': 139,
#  'brown': 140,
#  'chief': 141,
#  'problem': 142,
#  'growth': 143,
#  'hit': 144,
#  'industry': 145,
#  'law': 146,
#  'net': 147,
#  'six': 148,
#  'point': 149,
#  'lose': 150,
#  'cut': 151,
#  'britain': 152,
#  'four': 153,
#  'job': 154,
#  'continue': 155,
#  'former': 156,
#  'london': 157,
#  'state': 158,
#  'money': 159,
#  'late': 160,
#  'team': 161,
#  'rate': 162,
#  'figure': 163,
#  'rule': 164,
#  'thing': 165,
#  'leave': 166,
#  'computer': 167,
#  'club': 168,
#  'economic': 169,
#  'long': 170,
#  'allow': 171,
#  'release': 172,
#  'sell': 173,
#  'accord': 174,
#  'international': 175,
#  'decision': 176,
#  'digital': 177,
#  'network': 178,
#  'tax': 179,
#  'europe': 180,
#  'analyst': 181,
#  'court': 182,
#  'around': 183,
#  'consumer': 184}

# %%
w2v_model.wv.most_similar(positive=['british'])
# Out:
# [('star', 0.8749085068702698),
#  ('film', 0.8535154461860657),
#  ('director', 0.8463858366012573),
#  ('man', 0.8456218242645264),
#  ('award', 0.8255392909049988),
#  ('london', 0.805381715297699),
#  ('good', 0.8007272481918335),
#  ('include', 0.7904858589172363),
#  ('britain', 0.7447593212127686),
#  ('former', 0.7242653965950012)]

# %%
w2v_model.wv.similarity('believe', 'business')
# Out:
# 0.21482402

# %% [markdown]
# ## Visualise word vectors in two dimension

# %%
from sklearn.decomposition import PCA

# %%
w2v_model.wv.key_to_index
# Out:
# {'say': 0,
#  'mr': 1,
#  'year': 2,
#  'would': 3,
#  'make': 4,
#  'also': 5,
#  'people': 6,
#  'new': 7,
#  'we': 8,
#  'one': 9,
#  'take': 10,
#  'go': 11,
#  'good': 12,
#  'could': 13,
#  'use': 14,
#  'game': 15,
#  'get': 16,
#  'time': 17,
#  '£': 18,
#  'last': 19,
#  'first': 20,
#  'world': 21,
#  'government': 22,
#  'well': 23,
#  'come': 24,
#  'two': 25,
#  'see': 26,
#  'show': 27,
#  'film': 28,
#  'play': 29,
#  'company': 30,
#  'uk': 31,
#  'tell': 32,
#  'work': 33,
#  'firm': 34,
#  'give': 35,
#  'want': 36,
#  'add': 37,
#  'back': 38,
#  'win': 39,
#  'like': 40,
#  'number': 41,
#  'service': 42,
#  'include': 43,
#  'think': 44,
#  'way': 45,
#  'music': 46,
#  'month': 47,
#  'market': 48,
#  'many': 49,
#  'country': 50,
#  'player': 51,
#  'plan': 52,
#  'set': 53,
#  'labour': 54,
#  'need': 55,
#  'week': 56,
#  'next': 57,
#  'party': 58,
#  'report': 59,
#  'bbc': 60,
#  'three': 61,
#  'look': 62,
#  'big': 63,
#  'minister': 64,
#  'sale': 65,
#  'home': 66,
#  'election': 67,
#  'may': 68,
#  'call': 69,
#  'million': 70,
#  'day': 71,
#  'expect': 72,
#  'rise': 73,
#  'technology': 74,
#  'right': 75,
#  'find': 76,
#  'know': 77,
#  'second': 78,
#  'award': 79,
#  'mobile': 80,
#  'still': 81,
#  'group': 82,
#  'start': 83,
#  'part': 84,
#  'help': 85,
#  'england': 86,
#  'top': 87,
#  'end': 88,
#  'much': 89,
#  'claim': 90,
#  'phone': 91,
#  'since': 92,
#  'offer': 93,
#  'blair': 94,
#  'move': 95,
#  'high': 96,
#  'lead': 97,
#  'early': 98,
#  'try': 99,
#  'put': 100,
#  'share': 101,
#  'become': 102,
#  'public': 103,
#  'system': 104,
#  'record': 105,
#  'change': 106,
#  'run': 107,
#  'hold': 108,
#  'issue': 109,
#  'european': 110,
#  'star': 111,
#  'british': 112,
#  'deal': 113,
#  'believe': 114,
#  'increase': 115,
#  'great': 116,
#  'news': 117,
#  'follow': 118,
#  'place': 119,
#  'price': 120,
#  'however': 121,
#  'tv': 122,
#  'face': 123,
#  'bank': 124,
#  'even': 125,
#  'open': 126,
#  'director': 127,
#  'pay': 128,
#  'mean': 129,
#  'business': 130,
#  'five': 131,
#  'tory': 132,
#  'cost': 133,
#  'economy': 134,
#  'fall': 135,
#  'user': 136,
#  'hope': 137,
#  'already': 138,
#  'man': 139,
#  'brown': 140,
#  'chief': 141,
#  'problem': 142,
#  'growth': 143,
#  'hit': 144,
#  'industry': 145,
#  'law': 146,
#  'net': 147,
#  'six': 148,
#  'point': 149,
#  'lose': 150,
#  'cut': 151,
#  'britain': 152,
#  'four': 153,
#  'job': 154,
#  'continue': 155,
#  'former': 156,
#  'london': 157,
#  'state': 158,
#  'money': 159,
#  'late': 160,
#  'team': 161,
#  'rate': 162,
#  'figure': 163,
#  'rule': 164,
#  'thing': 165,
#  'leave': 166,
#  'computer': 167,
#  'club': 168,
#  'economic': 169,
#  'long': 170,
#  'allow': 171,
#  'release': 172,
#  'sell': 173,
#  'accord': 174,
#  'international': 175,
#  'decision': 176,
#  'digital': 177,
#  'network': 178,
#  'tax': 179,
#  'europe': 180,
#  'analyst': 181,
#  'court': 182,
#  'around': 183,
#  'consumer': 184}

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np

# %%
def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

# %%
x_vals, y_vals, labels = reduce_dimensions(w2v_model)

# %%
import matplotlib.pyplot as plt
import random
plt.rcParams["figure.figsize"] = (20,15)

# %%
plt.scatter(x_vals, y_vals)
# Loop for annotation of all points
for i in range(len(labels)):
    plt.annotate(labels[i], (x_vals[i], y_vals[i] + 0.2), fontsize=15, alpha=0.7)
